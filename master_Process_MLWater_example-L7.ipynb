# %% [markdown]
# # Non-DC ML water masks creation

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import glob
import shutil
from datetime import datetime
import pandas as pd
import time
import os

from subprocess import Popen, PIPE, STDOUT

from utils.genprepWater import per_scene_wofs
from utils.prep_utils import s3_list_objects_paths

# %%
# # should encode to env vars as with docker, not csv
# os.environ['AWS_ACCESS_KEY_ID']= str(pd.read_csv('../aws_creds.csv').AWSAccessKeyId.values[0])
# os.environ['AWS_SECRET_ACCESS_KEY']= str(pd.read_csv('../aws_creds.csv').AWSSecretKey.values[0])
# # os.environ['AWS_S3_ENDPOINT']=str(pd.read_csv('../aws_creds.csv').AWS_S3_ENDPOINT.values[0])
print(os.environ['AWS_ACCESS_KEY_ID'])
print(os.environ['AWS_S3_ENDPOINT'])
# Out:
# 16c353e3c1673eb9556e
# s3-uk-1.sa-catapult.co.uk

# %% [markdown]
# # **Example job**

# %% [markdown]
# essential **input vars**

# %%
# essential input vars
s3_bucket = 'public-eo-data'
s3_dir = 'common_sensing/tom/mlperscene_test/'
inter_dir = '../data/'
coast_buffer = 'common_sensing/ancillary_products/Buffers/Fiji_1kmBuffer_shp'

# %% [markdown]
# find **list of scene yamls** - this is essentially input to the job list

# %%
s3_dir_allprods = 'common_sensing/fiji/'
# prep to single yaml path
s3_paths = s3_list_objects_paths(s3_bucket, s3_dir_allprods)
yamls = [i for i in s3_paths if i.split('/')[-1][-4:] == 'yaml']
len(yamls)
# Out:
# 11648

# %% [markdown]
# filter to **yamls of test scenes** - i.e. scenes from desired sensors that are largely spatially covered by and within preceeding year to Annual Wofs Water Summary test aoi and year

# %%
ys = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
print("YEAR  |  L7  |  L8  |  S2  |  S1")
s1_ymls_all = []
for y in ys:
#     l7_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'landsat_7') & ('074072' in i) & (y == i.split('/')[3].split('_')[-1][:4])])
#     l8_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'landsat_8') & ('074072' in i) & (y == i.split('/')[3].split('_')[-1][:4])])
#     s2_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'sentinel_2') & ('60KXF' in i ) & (y in i)])
#     s1_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'sentinel_1') & (y in i)])
    l7_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'landsat_7') & (y == i.split('/')[3].split('_')[-1][:4])])
    l8_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'landsat_8') & (y == i.split('/')[3].split('_')[-1][:4])])
    s2_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'sentinel_2') & (y in i)])
    s1_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'sentinel_1') & (y in i)])
    s1_ymls_all.append(l8_ymls)
    print(y, len(l7_ymls), len(l8_ymls), len(s2_ymls), len(s1_ymls))
# Out:
# YEAR  |  L7  |  L8  |  S2  |  S1
# 2000 73 0 0 0
# 2001 77 0 0 9
# 2002 64 0 0 3
# 2003 77 0 0 0
# 2004 125 0 0 0
# 2005 129 0 0 0
# 2006 146 0 0 0
# 2007 89 0 0 0
# 2008 125 0 0 0
# 2009 124 0 0 0
# 2010 136 0 0 0
# 2011 93 0 0 0
# 2012 132 0 0 0
# 2013 115 153 0 0
# 2014 0 376 0 0
# 2015 0 408 0 0
# 2016 0 410 0 0
# 2017 0 429 0 69
# 2018 0 437 233 86
# 2019 0 304 2298 86
# 2020 0 0 0 12

# %%
s1_ymls_all
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['common_sensing/fiji/landsat_8/LC08_L1TP_072069_20130522/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20130826/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20131029/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20131130/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20131216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20130522/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20130826/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20131029/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20131114/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20131130/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20131216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20130522/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20130826/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20130911/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20130927/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20131013/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20131029/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20131114/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20131130/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20131216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20130522/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20130826/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20130911/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20130927/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20131013/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20131029/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20131114/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20131130/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20131216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20130522/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20130826/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20130911/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20130927/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20131013/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20131029/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20131114/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20131130/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20131216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20130427/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20130902/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20130918/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20131105/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20131121/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20131207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20130427/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20130902/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20130918/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20131004/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20131105/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20131121/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20131207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20131223/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20130427/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20130529/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20130902/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20130918/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20131004/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20131105/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20131121/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20131207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20131223/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20130902/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20130918/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20131004/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20131121/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20131207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20131223/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20130520/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20130824/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20131027/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20131112/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20131128/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20131214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20131230/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130520/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130621/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130707/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130723/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130808/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130824/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130909/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20130925/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20131011/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20131027/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20131128/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20131214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20131230/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130520/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130605/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130621/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130707/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130723/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130808/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130824/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130909/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20130925/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20131011/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20131027/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20131112/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20131128/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20131214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20131230/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130621/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130707/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130723/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130808/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130824/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130909/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20130925/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20131011/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20131027/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20131112/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20131128/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20131214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20131230/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20130425/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20130831/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20131103/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20131119/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20131205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20131221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20130425/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20130831/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20130916/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20131002/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20131018/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20131119/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20131205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20131221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20130425/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20130527/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20130831/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20130916/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20131002/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20131018/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20131119/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20131205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20131221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20130831/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20130916/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20131002/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20131018/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20131119/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20131205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20131221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20130822/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20130907/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20130923/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20131009/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20131110/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20131126/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20131212/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20131228/datacube-metadata.yaml'],
#  ['common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140218/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140306/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140322/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140407/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140423/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140509/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140610/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140712/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140728/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140813/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140829/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140914/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20140930/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20141016/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20141101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20141117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20141203/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20141219/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140202/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140218/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140306/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140322/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140407/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140423/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140509/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140525/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140610/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140712/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140728/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140813/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140829/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140914/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20140930/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20141016/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20141101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20141117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20141203/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20141219/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140202/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140218/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140306/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140322/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140407/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140423/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140509/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140525/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140610/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140712/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140728/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140813/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140829/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140914/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20140930/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20141016/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20141101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20141117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20141203/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072072_20141219/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140202/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140306/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140322/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140407/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140423/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140509/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140525/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140610/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140712/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140728/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140813/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140829/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140914/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20140930/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20141016/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20141101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20141117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20141203/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072073_20141219/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140306/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140322/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140407/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140423/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140509/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140525/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140610/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140712/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140728/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140813/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140829/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140914/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20140930/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20141016/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20141101/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20141117/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20141203/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072074_20141219/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140124/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140209/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140313/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140329/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140414/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140430/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140516/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140601/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140617/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140703/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140719/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140804/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140820/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140905/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20140921/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20141007/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20141023/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20141108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20141124/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20141210/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073069_20141226/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140209/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140313/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140329/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140414/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140430/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140516/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140601/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140617/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140703/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140719/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140804/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140820/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140905/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20140921/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20141007/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20141023/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20141108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20141124/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20141210/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073071_20141226/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140209/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140225/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140313/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140329/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140414/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140430/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140516/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140601/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140617/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140703/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140719/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140804/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140820/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140905/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20140921/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20141007/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20141023/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20141108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20141124/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20141210/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20141226/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140124/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140209/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140313/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140329/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140414/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140430/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140601/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140617/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140703/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140719/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140804/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140820/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140905/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20140921/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20141007/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20141023/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20141108/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20141124/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20141210/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20141226/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140304/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140320/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140405/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140421/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140507/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140523/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140608/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140624/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140710/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140726/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140811/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140827/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140912/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20140928/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20141014/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20141030/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20141115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20141201/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20141217/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140304/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140320/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140421/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140507/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140523/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140608/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140624/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140710/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140726/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140811/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140827/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140912/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20140928/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20141014/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20141030/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20141115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20141201/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20141217/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140131/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140304/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140320/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140405/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140421/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140507/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140523/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140608/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140624/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140710/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140726/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140811/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140827/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140912/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20140928/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20141014/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20141030/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20141115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20141201/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20141217/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140131/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140216/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140304/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140320/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140405/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140421/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140507/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140523/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140608/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140624/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140710/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140726/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140811/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140827/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140912/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20140928/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20141014/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20141030/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20141115/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20141201/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20141217/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140327/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140412/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140428/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140514/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140530/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140615/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140701/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140717/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140802/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140818/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140903/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20140919/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20141005/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20141021/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20141106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20141122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20141208/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20141224/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140327/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140412/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140428/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140514/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140530/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140615/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140701/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140717/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140802/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140818/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140903/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20140919/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20141005/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20141021/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20141106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20141122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20141208/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20141224/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140311/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140327/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140412/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140428/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140514/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140530/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140615/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140701/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140717/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140802/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140818/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140903/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20140919/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20141005/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20141021/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20141106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20141122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20141208/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20141224/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140223/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140327/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140412/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140514/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140530/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140615/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140701/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140717/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140802/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140818/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140903/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20140919/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20141005/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20141021/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20141106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20141122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20141208/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20141224/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140113/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140318/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140403/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140419/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140521/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140606/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140622/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140708/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140809/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140825/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140910/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20140926/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20141012/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20141028/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20141113/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20141129/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20141215/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20141231/datacube-metadata.yaml'],
#  ['common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150309/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150325/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150410/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150426/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150512/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150528/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150613/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150629/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150715/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150731/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150816/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150901/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20150917/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20151003/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20151019/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20151104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20151120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20151206/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072069_20151222/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150309/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150325/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150410/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150426/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150512/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150528/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150613/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150629/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150715/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150731/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150816/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150901/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20150917/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_072071_20151003/datacube-metadata.yaml',
# ...
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190223/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190311/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190327/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190412/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190428/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190514/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190530/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190615/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190701/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190717/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190802/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190818/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073072_20190903/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190106/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190122/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190207/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190223/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190311/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190327/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190412/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190428/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190514/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190530/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190615/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190701/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190717/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190802/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190818/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_073073_20190903/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190113/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190129/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190302/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190318/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190403/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190419/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190505/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190521/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190606/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190622/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190708/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190724/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190809/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190825/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074069_20190910/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190113/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190129/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190302/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190318/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190403/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190419/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190505/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190521/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190606/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190622/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190708/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190724/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190809/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190825/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074071_20190910/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190113/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190129/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190302/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190318/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190403/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190419/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190505/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190521/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190606/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190622/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190708/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190724/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190809/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190825/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074072_20190910/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190113/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190129/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190214/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190302/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190318/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190403/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190419/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190505/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190521/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190606/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190622/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190708/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190724/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190809/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190825/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_074073_20190910/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190309/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190325/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190410/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190426/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190512/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190528/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190613/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190629/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190715/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190731/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190816/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075069_20190901/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190309/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190325/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190410/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190426/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190512/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190528/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190613/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190629/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190715/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190731/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190816/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075071_20190901/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190309/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190325/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190410/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190426/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190512/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190528/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190613/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190629/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190715/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190731/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190816/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075072_20190901/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190104/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190120/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190205/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190221/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190309/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190325/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190410/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190426/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190512/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190528/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190613/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190629/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190715/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190731/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190816/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_075073_20190901/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190111/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190127/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190212/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190228/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190316/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190401/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190417/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190503/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190519/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190604/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190620/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190706/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190722/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190807/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190823/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076069_20190908/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190111/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190127/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190212/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190228/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190316/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190401/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190417/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190503/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190519/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190604/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190620/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190706/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190722/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190807/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190823/datacube-metadata.yaml',
#   'common_sensing/fiji/landsat_8/LC08_L1TP_076071_20190908/datacube-metadata.yaml'],
#  []]

# %%
y = '2013'
l7_ymls = sorted([i for i in yamls if (i.split('/')[2] == 'landsat_7') & ('074072' in i) & (y == i.split('/')[3].split('_')[-1][:4])])

# %% [markdown]
# filter yamls to find list of **available annual water summary** products

# %%
wofssummary_ymls = [i for i in yamls if (i.split('/')[2] == 'wofs_summary') & ('2013' in i)]
len(wofssummary_ymls)
# Out:
# 1

# %% [markdown]
# example **job function**

# %%
# for sc in nice_scenes[:]:
#     per_scene_wofs(sc, s3_bucket='cs-odc-data', s3_dir='tom/water_classification_landsat_test/', inter_dir='../wofs_landsat/', aoi_mask='tom/ancillary/Fiji_1kmBuffer.geojson')

# %% [markdown]
# # **Walkthroughs**

# %%
import yaml
import glob
import rasterio
from rasterio.crs import CRS
# from rasterio.transform import Affine
from affine import Affine
import rioxarray
import xarray as xr
from matplotlib import pyplot as plt
from datetime import datetime
from subprocess import Popen, PIPE, STDOUT
import pandas as pd
import os
import numpy as np
import shutil
import logging
import logging.handlers
from dateutil.parser import parse
import uuid
import geopandas as gpd
import rasterio
import rasterio.features
import gdal
import gc
import traceback

# ml stuff
from sklearn_xarray import wrap
from sklearn.ensemble import RandomForestClassifier

from utils.dc_water_classifier import wofs_classify
from utils.dc_clean_mask import landsat_qa_clean_mask
from utils.prep_utils import s3_list_objects, s3_download, s3_upload_cogs, create_yaml, cog_translate, get_geometry
from utils.dc_import_export import export_xarray_to_geotiff

# %%
def resamp_bands(xr, xrs):
    if xr.attrs['res'] == xrs[0].attrs['res']:
        return xr
    else:
        return xr.interp(x=xrs[0]['x'], y=xrs[0]['y'], method='nearest') # nearest as exclusively upsampling
    
def rename_bands(in_xr, des_bands, position):
    in_xr.name = des_bands[position]
    return in_xr

def get_valid(ds, prod):
    # Identify pixels with valid data
    if 'LANDSAT_8' in prod:
        good_quality = (
            (ds.pixel_qa == 322)  | # clear
            (ds.pixel_qa == 386)  |
            (ds.pixel_qa == 834)  |
            (ds.pixel_qa == 898)  |
            (ds.pixel_qa == 1346) |
            (ds.pixel_qa == 324)  | # water
            (ds.pixel_qa == 388)  |
            (ds.pixel_qa == 836)  |
            (ds.pixel_qa == 900)  |
            (ds.pixel_qa == 1348)
        )
    elif prod in ["LANDSAT_7", "LANDSAT_5", "LANDSAT_4"]:    
        good_quality = (
            (ds.pixel_qa == 66)   | # clear
            (ds.pixel_qa == 130)  |
            (ds.pixel_qa == 68)   | # water
            (ds.pixel_qa == 132)  
        )
    elif 'SENTINEL_2' in prod:
        good_quality = (
            (ds.scene_classification == 2) | # mask in DARK_AREA_PIXELS
#             (ds.scene_classification == 3) | # mask in CLOUD_SHADOWS
            (ds.scene_classification == 4) | # mask in VEGETATION
            (ds.scene_classification == 5) | # mask in NOT_VEGETATED
            (ds.scene_classification == 6) | # mask in WATER
            (ds.scene_classification == 7)   # mask in UNCLASSIFIED
        )
    elif 'WOFS_SUMMARY' in prod:
        good_quality = (
            (ds >= 0)
        )
    elif 'SENTINEL_1' in prod:
        good_quality = (
            (ds.vv != 0)
        )
    return good_quality

def get_ref_channel(prod):
    if ('LANDSAT' in prod) | ('SENTINEL_2' in prod): return 'swir1'
    elif 'SENTINEL_1' in prod: return 'vv'
    
def get_qa_channel(prod):
    if 'LANDSAT' in prod: return 'pixel_qa'
    elif 'SENTINEL_2' in prod: return 'scene_classification'
    elif 'SENTINEL_1' in prod: return 'layovershadow_mask'
    

def band_name_water(prod_path):
    """
    Determine l8 band of individual product from product name
    from path to specific product file
    """

    prod_name = os.path.basename(prod_path)
    parts = prod_name.split('_')
    prod_name = f"{parts[-2]}_{parts[-1][:-4]}"

    prod_map = {
        "watermask": 'watermask',
        "waterprob": 'waterprob'
    }
    layer_name = prod_map[prod_name]
    return layer_name

def yaml_prep_water(scene_dir, original_yml):
    """
    Prepare individual wofs directory containing L8/S2/S1 cog water products.
    """
    # scene_name = scene_dir.split('/')[-2][:26]
    scene_name = scene_dir.split('/')[-2]
    print ( "Preparing scene {}".format(scene_name) )
    print ( "Scene path {}".format(scene_dir) )
    
    # find all cog prods
    prod_paths = glob.glob(scene_dir + '*water*.tif')
    # print ( 'paths: {}'.format(prod_paths) )
    # for i in prod_paths: print ( i )
    
    # date time assumed eqv for start and stop - this isn't true and could be 
    # pulled from .xml file (or scene dir) not done yet for sake of progression
    t0=parse(str(datetime.strptime(original_yml['extent']['center_dt'], '%Y-%m-%d %H:%M:%S')))
    # print ( t0 )
    t1=t0
    # print ( t1 )
    
    # name image product
    images = {
        prod_path.split('_')[-1][:9]: {
            'path': str(prod_path.split('/')[-1])
        } for prod_path in prod_paths
    }
    print ( images )

    # trusting bands coaligned, use one to generate spatial bounds for all
    projection, extent = get_geometry(os.path.join(str(scene_dir), images['watermask']['path']))
#     extent = 
    print(projection, extent)
    
    new_id = str(uuid.uuid5(uuid.NAMESPACE_URL, f"{scene_name}_water"))
    
    return {
        'id': new_id,
        'processing_level': original_yml['processing_level'],
        'product_type': "mlwater",
        'creation_dt': str(datetime.today().strftime('%Y-%m-%d %H:%M:%S')),
        'platform': {  
            'code': original_yml['platform']['code']
        },
        'instrument': {
            'name': original_yml['instrument']['name']
        },
        'extent': {
            'coord': original_yml['extent']['coord'],
            'from_dt': str(t0),
            'to_dt': str(t1),
            'center_dt': str(t0 + (t1 - t0) / 2)
        },
        'format': {
            'name': 'GeoTiff'
        },
        'grid_spatial': {
            'projection': projection
        },
        'image': {
            'bands': images
        },
        'lineage': {
            'source_datasets': original_yml['lineage']['source_datasets'],
        }  
    }


def mlwater(optical_yaml_path, summary_yaml_path, inter_dir='../data/', s3_bucket='public-eo-data', s3_dir='common_sensing/fiji/mlwater_test/',
            mask=None, output_crs=None):
    """
    optical_yaml_path: dc yml metadata of single image within S3 bucket
    summary_yaml_path: dc yml metadata of wofs-like summary product within S3 bucket
    """

    try: 
        
        scene_name = os.path.dirname(optical_yaml_path).split('/')[-1]
        
        inter_dir = f"{inter_dir}{scene_name}_tmp/"
        os.makedirs(inter_dir, exist_ok=True)
        cog_dir = f"{inter_dir}{scene_name}/"
        os.makedirs(cog_dir, exist_ok=True)
        
        yml = f'{inter_dir}datacube-metadata.yaml'
        yml_summary = f'{inter_dir}datacube-metadata_watersummary.yaml'
        
        des_band_refs = {
            "LANDSAT_8": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
            "LANDSAT_7": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
            "LANDSAT_5": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
            "LANDSAT_4": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
            "SENTINEL_2": ['blue','green','red','nir','swir1','swir2','scene_classification'],
            "SENTINEL_1": ['vv','vh','layovershadow_mask'],
            "WOFS_SUMMARY": ['pc']}
        
        if not os.path.exists(yml):
            s3_download(s3_bucket, optical_yaml_path, yml)
            with open (yml) as stream: yml_meta = yaml.safe_load(stream)
            satellite = yml_meta['platform']['code'] # helper to generalise masking 
            des_bands = des_band_refs[satellite]
            print(satellite, des_bands)
            band_paths_s3 = [os.path.dirname(optical_yaml_path)+'/'+yml_meta['image']['bands'][b]['path'] for b in des_bands ]
            band_paths_local = [inter_dir+os.path.basename(i) for i in band_paths_s3]
            for s3, loc in zip(band_paths_s3, band_paths_local): 
                if not os.path.exists(loc):
                    s3_download(s3_bucket, s3, loc)
        elif os.path.exists(yml):
            with open (yml) as stream: yml_meta = yaml.safe_load(stream)
            satellite = yml_meta['platform']['code'] # helper to generalise masking 
            des_bands = des_band_refs[satellite]
            print(satellite, des_bands)
        else:
            print('boo')

        # FIND & DOWNLOAD WATER SUMMARY DATA
        if not os.path.exists(yml_summary):
            s3_download(s3_bucket, summary_yaml_path, yml_summary)
            with open (yml_summary) as stream: yml_summary_meta = yaml.safe_load(stream)
            summary = yml_summary_meta['platform']['code']
            des_bands_summary = des_band_refs[summary]
            print(summary, des_bands_summary)
            band_paths_s3 = [os.path.dirname(summary_yaml_path)+'/'+yml_summary_meta['image']['bands'][b]['path'] for b in des_bands_summary ]
            band_paths_local = [inter_dir+os.path.basename(i) for i in band_paths_s3]
            for s3, loc in zip(band_paths_s3, band_paths_local): 
                if not os.path.exists(loc):
                    s3_download(s3_bucket, s3, loc)
        elif os.path.exists(yml_summary):
            s3_download(s3_bucket, summary_yaml_path, yml_summary)
            with open (yml_summary) as stream: yml_summary_meta = yaml.safe_load(stream)
            summary = yml_summary_meta['platform']['code']
            des_bands_summary = des_band_refs[summary]
            print(summary, des_bands_summary)
            band_paths_s3 = [os.path.dirname(summary_yaml_path)+'/'+yml_summary_meta['image']['bands'][b]['path'] for b in des_bands_summary ]
            band_paths_local = [inter_dir+os.path.basename(i) for i in band_paths_s3]
            for s3, loc in zip(band_paths_s3, band_paths_local): 
                if not os.path.exists(loc):
                    s3_download(s3_bucket, s3, loc)
        else:
            print('boo')

        ref_channel = get_ref_channel(satellite)
        qa_channel = get_qa_channel(satellite)
        print(ref_channel, qa_channel)

        # LOAD & PREP IMAGE DATA
        o_bands_data = [ xr.open_rasterio(inter_dir + yml_meta['image']['bands'][b]['path']) for b in des_bands ] # loading
        o_bands_data = [ resamp_bands(i, o_bands_data) for i in o_bands_data ] # resamp 2 match band 1
        bands_data = xr.merge([rename_bands(bd, des_bands, i) for i,bd in enumerate(o_bands_data)]).rename({'band': 'time'}) # ensure band names & dims consistent
        bands_data = bands_data.assign_attrs(o_bands_data[0].attrs) # crs etc. needed later
        bands_data['time'] = [datetime.strptime(yml_meta['extent']['center_dt'], '%Y-%m-%d %H:%M:%S')] # time dim needed for wofs

        img_data = bands_data.isel(time = 0).drop(['time'])
        bands_data = None
        o_bands_data = None
        
        # LOAD & PREP WATER SUMMARY DATA
        o_bands_data = [ xr.open_rasterio(inter_dir + yml_summary_meta['image']['bands'][b]['path']) for b in des_bands_summary ] # loading
        o_bands_data = [ resamp_bands(i, o_bands_data) for i in o_bands_data ]
        sum_data = xr.merge([rename_bands(bd, des_bands_summary, i) for i,bd in enumerate(o_bands_data)]).rename({'band': 'time'}) # ensure band names & dims consistent
        sum_data = sum_data.assign_attrs(o_bands_data[0].attrs) # crs etc. needed later
        sum_data['time'] = [datetime.strptime(yml_summary_meta['extent']['center_dt'], '%Y-%m-%d %H:%M:%S')] # time dim needed for wofs

        class_data = sum_data.isel(time = 0).drop(['time']).pc
        sum_data = None
        o_bands_data = None
        
        # REPROJECT & ALIGN CRS+DIMS
        class_data = class_data.rio.reproject_match(img_data[ref_channel]) # repro + align grid
        img_data, class_data = xr.align(img_data, class_data, join="override") # force alignment of x,y precision
        
        if satellite == 'SENTINEL_1': # catch s1 and scall and re-fromat dtype
            att = img_data.attrs
            img_data = img_data*100
            img_data = img_data.astype('int16')
            img_data.attrs = att
        
        # VALID REGION MASKS
        clearskymask_img = get_valid(img_data, satellite) # img nd mask
        clearskymask_class = get_valid(class_data, summary) # water nd mask
        clearskymask_train = clearskymask_class.where(clearskymask_class == False, False) # empty mask
        clearskymask_train = clearskymask_train.where((clearskymask_img == False) | (clearskymask_class == False), True) # inner true mask
        
        # ASSIGN WATER/NON WATER CLASS LABELS
        water_thresh = 50 # 50% persistence in annual summary
        class_data = class_data.where((class_data < water_thresh) | (clearskymask_class == False), 100) # fix > prob to water
        class_data = class_data.where((class_data >= water_thresh) | (clearskymask_class == False), 0) # fix < prob to no water 
        
        # MASK TO TRAINING SAMPLES W/ IMPUTED ND
        train_data = img_data # dup as use img 4 implementation later
        train_data['waterclass'] = class_data # add channel for water mask
        train_data = train_data.where(clearskymask_train == True, -9999).drop([qa_channel]) # apply inner mask
        
        unique, counts = np.unique(train_data.waterclass, return_counts=True)
        if (counts[0] < 500) | (counts[1] < 5000):
            raise Exception(f'no class labels should be >5000 for ok classifier. no. training class samples: {counts[0]}{counts[1]}')
        
        # SPEC & TRAIN MODEL
        Y = train_data.waterclass.stack(z=['x','y']) # stack into 1-d arr
        X = train_data.drop(['waterclass']).stack(z=['x','y']).to_array().transpose() # stack into transposed 2-d arr
        # very shallow classifier - this is a super easy problem & we want it to be fast
        wrapper = wrap(RandomForestClassifier(n_estimators=2, 
                                       bootstrap = True,
                                       max_features = 'sqrt',
                                       max_depth=5,
                                       n_jobs=2,
                                       verbose=2
                                      ))
        wrapper.estimator.fit(X, Y) # do training
        
        # MASK TO FULL VALID IMAGE FOR IMPLEMENTATION
        img_data = img_data.drop([qa_channel,'waterclass']) # not sure how these ended up in here(?)
        img_data = img_data.where(clearskymask_img == True, -9999) # apply just the img mask this time
        
        # PREDICT + ASSIGN CONFIDENCE
        X = img_data.stack(z=['x','y']).to_array().transpose() # stack into transposed 2-d arr

        pred = wrapper.estimator.predict(X) # gen class predictions
        pred[pred==100] = 1 # refactor water from 100 to 1
        prob = wrapper.estimator.predict_proba(X)[:,2]*100 # gen confidence in assigned labels as int
        
        # RESHAPE OUTPUTS INTO IMAGE
        vars_0 = [i for i in X.transpose().to_dataset(dim='variable').data_vars] # get list of vars within img
        X_t = X.transpose().to_dataset(dim='variable') # recreate xrds (but no unstacking yet as need to drop in model outputs)
        X_t[vars_0[0]].data = pred # add class predictions as first channel
        X_t[vars_0[1]].data = prob # add confidence as second channel
        X_t = X_t.rename({vars_0[0]:'water_mask',vars_0[1]:'water_prob'}).drop(vars_0[2:]).unstack('z').transpose().astype('int16') # rename + drop vars + unstack xy dims back to 3-d xrds + transpose predictions back into correct orientation
        X_t = X_t.where(clearskymask_img,-9999) # ensure probs rm 4 nd regions
        X_t.attrs = img_data.attrs

        # EXPORT
        inter_prodir = inter_dir + scene_name + '_mlwater/'
        os.makedirs(inter_prodir, exist_ok=True)
        out_mask_prod = inter_prodir + scene_name + '_watermask.tif'
        out_prob_prod = inter_prodir + scene_name + '_waterprob.tif'
        output_crs = f"EPSG:{X_t.attrs['crs'].split(':')[-1]}"
        export_xarray_to_geotiff(X_t, out_mask_prod, bands=['water_mask'], crs=output_crs, x_coord='x', y_coord='y', no_data=-9999)
        export_xarray_to_geotiff(X_t, out_prob_prod, bands=['water_prob'], crs=output_crs, x_coord='x', y_coord='y', no_data=-9999)
        
        # CREATE YML
        create_yaml(inter_prodir, yaml_prep_water(inter_prodir, yml_meta)) # assumes majority of meta copied from original product yml
        
        # UPLOAD
        s3_upload_cogs(glob.glob(f'{inter_prodir}*'), s3_bucket, s3_dir)
        
        class_data = None
        att = None
        img_data = None
        clearskymask_img = None
        clearskymask_class = None
        clearskymask_train = None
        class_data = None
        train_data = None
        wrapperper = None
        X = None     
        Y = None
        pred = None
        prob = None
        vars_0 = None
        X_t = None
        
        gc.collect()
#         shutil.rmtree(inter_prodir)

    except Exception as e:
        print(e)
        traceback.print_exc()

        class_data = None
        att = None
        img_data = None
        clearskymask_img = None
        clearskymask_class = None
        clearskymask_train = None
        class_data = None
        train_data = None
        wrapperper = None
        X = None     
        Y = None
        pred = None
        prob = None
        vars_0 = None
        X_t = None

        gc.collect()
#         shutil.rmtree(inter_prodir)

# %%
p = l8_ymls[:5] + s1_ymls[:5] +s2_ymls[:5]

# %%
for i in l7_ymls:
    mlwater(i, wofssummary_ymls[0])
# Out:
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   17.9s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.6s finished
# Preparing scene LE07_L1TP_074072_20130104_mlwater
# Scene path ../data/LE07_L1TP_074072_20130104_tmp/LE07_L1TP_074072_20130104_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130104_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130104_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 575700.0, 'y': -1812300.0}, 'ur': {'x': 818700.0, 'y': -1812300.0}, 'll': {'x': 575700.0, 'y': -2023800.0}, 'lr': {'x': 818700.0, 'y': -2023800.0}}} {'ul': {'lon': -16.390832175828276, 'lat': 177.7089115266493}, 'ur': {'lon': -16.370873203716542, 'lat': 179.98316443601072}, 'll': {'lon': -18.302481070878454, 'lat': 177.7162938328214}, 'lr': {'lon': -18.280042965675328, 'lat': -179.98582391936708}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   26.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.0s finished
# Preparing scene LE07_L1TP_074072_20130120_mlwater
# Scene path ../data/LE07_L1TP_074072_20130120_tmp/LE07_L1TP_074072_20130120_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130120_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130120_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 576300.0, 'y': -1812600.0}, 'ur': {'x': 819600.0, 'y': -1812600.0}, 'll': {'x': 576300.0, 'y': -2024100.0}, 'lr': {'x': 819600.0, 'y': -2024100.0}}} {'ul': {'lon': -16.393524975049758, 'lat': 177.7145399489992}, 'ur': {'lon': -16.37346200362568, 'lat': 179.9916218404828}, 'll': {'lon': -18.30517098654163, 'lat': 177.72198209806703}, 'lr': {'lon': -18.28261633039153, 'lat': -179.97727372415585}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2
# building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   31.9s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.4s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.9s finished
# Preparing scene LE07_L1TP_074072_20130205_mlwater
# Scene path ../data/LE07_L1TP_074072_20130205_tmp/LE07_L1TP_074072_20130205_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130205_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130205_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 574800.0, 'y': -1812900.0}, 'ur': {'x': 817800.0, 'y': -1812900.0}, 'll': {'x': 574800.0, 'y': -2023500.0}, 'lr': {'x': 817800.0, 'y': -2023500.0}}} {'ul': {'lon': -16.396284052224836, 'lat': 177.7005030991576}, 'ur': {'lon': -16.37640908625005, 'lat': 179.97483048535858}, 'll': {'lon': -18.299801516852153, 'lat': 177.70776725999667}, 'lr': {'lon': -18.277469180397016, 'lat': -179.9943739166201}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2
# building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   25.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    6.5s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    6.4s finished
# Preparing scene LE07_L1TP_074072_20130309_mlwater
# Scene path ../data/LE07_L1TP_074072_20130309_tmp/LE07_L1TP_074072_20130309_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130309_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130309_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 575700.0, 'y': -1812900.0}, 'ur': {'x': 819000.0, 'y': -1812900.0}, 'll': {'x': 575700.0, 'y': -2023500.0}, 'lr': {'x': 819000.0, 'y': -2023500.0}}} {'ul': {'lon': -16.396255805078418, 'lat': 177.70893114830594}, 'ur': {'lon': -16.376250054377824, 'lat': 179.98605230935485}, 'll': {'lon': -18.29976977677542, 'lat': 177.7162826893261}, 'lr': {'lon': -18.277290487920766, 'lat': -179.98303635046872}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2
# building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   29.5s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.7s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.2s finished
# Preparing scene LE07_L1TP_074072_20130325_mlwater
# Scene path ../data/LE07_L1TP_074072_20130325_tmp/LE07_L1TP_074072_20130325_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130325_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130325_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 577800.0, 'y': -1812600.0}, 'ur': {'x': 821400.0, 'y': -1812600.0}, 'll': {'x': 577800.0, 'y': -2024100.0}, 'lr': {'x': 821400.0, 'y': -2024100.0}}} {'ul': {'lon': -16.393476779034035, 'lat': 177.7285864473574}, 'ur': {'lon': -16.37322193129668, 'lat': -179.9915459823277}, 'll': {'lon': -18.305116804197585, 'lat': 177.73617486321365}, 'lr': {'lon': -18.282346446299478, 'lat': -179.96026719177812}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   20.6s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.1s finished
# Preparing scene LE07_L1TP_074072_20130410_mlwater
# Scene path ../data/LE07_L1TP_074072_20130410_tmp/LE07_L1TP_074072_20130410_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130410_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130410_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 576000.0, 'y': -1812900.0}, 'ur': {'x': 819300.0, 'y': -1812900.0}, 'll': {'x': 576000.0, 'y': -2023800.0}, 'lr': {'x': 819300.0, 'y': -2023800.0}}} {'ul': {'lon': -16.396246314305984, 'lat': 177.71174049433176}, 'ur': {'lon': -16.376210203168867, 'lat': 179.98885774593165}, 'll': {'lon': -18.302470404826114, 'lat': 177.7191323495428}, 'lr': {'lon': -18.279953437645197, 'lat': -179.9801550811713}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   30.3s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.7s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.9s finished
# Preparing scene LE07_L1TP_074072_20130512_mlwater
# Scene path ../data/LE07_L1TP_074072_20130512_tmp/LE07_L1TP_074072_20130512_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130512_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130512_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 576600.0, 'y': -1812300.0}, 'ur': {'x': 819900.0, 'y': -1812300.0}, 'll': {'x': 576600.0, 'y': -2023800.0}, 'lr': {'x': 819900.0, 'y': -2023800.0}}} {'ul': {'lon': -16.390803600898398, 'lat': 177.71733932592645}, 'ur': {'lon': -16.370713779916095, 'lat': 179.994385857801}, 'll': {'lon': -18.302448946195224, 'lat': 177.72480937713135}, 'lr': {'lon': -18.279863741973276, 'lat': -179.97448627563796}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   26.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.6s finished
# Preparing scene LE07_L1TP_074072_20130629_mlwater
# Scene path ../data/LE07_L1TP_074072_20130629_tmp/LE07_L1TP_074072_20130629_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130629_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130629_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 577200.0, 'y': -1812300.0}, 'ur': {'x': 820500.0, 'y': -1812300.0}, 'll': {'x': 577200.0, 'y': -2023800.0}, 'lr': {'x': 820500.0, 'y': -2023800.0}}} {'ul': {'lon': -16.390784363370052, 'lat': 177.7229578494312}, 'ur': {'lon': -16.370633844324967, 'lat': 179.9999965219434}, 'll': {'lon': -18.302427318863582, 'lat': 177.73048639686303}, 'lr': {'lon': -18.279773878663786, 'lat': -179.96881750282802}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2
# building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   21.2s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.6s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.6s finished
# Preparing scene LE07_L1TP_074072_20130715_mlwater
# Scene path ../data/LE07_L1TP_074072_20130715_tmp/LE07_L1TP_074072_20130715_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130715_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130715_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 578100.0, 'y': -1812600.0}, 'ur': {'x': 821400.0, 'y': -1812600.0}, 'll': {'x': 578100.0, 'y': -2024100.0}, 'lr': {'x': 821400.0, 'y': -2024100.0}}} {'ul': {'lon': -16.393467027267207, 'lat': 177.73139574135473}, 'ur': {'lon': -16.37322193129668, 'lat': -179.9915459823277}, 'll': {'lon': -18.305105841184204, 'lat': 177.73901341028838}, 'lr': {'lon': -18.282346446299478, 'lat': -179.96026719177812}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2
# building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   36.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.6s finished
# Preparing scene LE07_L1TP_074072_20130731_mlwater
# Scene path ../data/LE07_L1TP_074072_20130731_tmp/LE07_L1TP_074072_20130731_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130731_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130731_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 578400.0, 'y': -1812300.0}, 'ur': {'x': 821700.0, 'y': -1812300.0}, 'll': {'x': 578400.0, 'y': -2023800.0}, 'lr': {'x': 821700.0, 'y': -2023800.0}}} {'ul': {'lon': -16.39074543813717, 'lat': 177.734194873745}, 'ur': {'lon': -16.370473525779474, 'lat': -179.98878224356824}, 'll': {'lon': -18.30238355810215, 'lat': 177.74184041250976}, 'lr': {'lon': -18.279593649148964, 'lat': -179.95748005562274}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   34.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.0s finished
# Preparing scene LE07_L1TP_074072_20130816_mlwater
# Scene path ../data/LE07_L1TP_074072_20130816_tmp/LE07_L1TP_074072_20130816_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130816_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130816_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 577200.0, 'y': -1812300.0}, 'ur': {'x': 820800.0, 'y': -1812300.0}, 'll': {'x': 577200.0, 'y': -2024100.0}, 'lr': {'x': 820800.0, 'y': -2024100.0}}} {'ul': {'lon': -16.390784363370052, 'lat': 177.7229578494312}, 'ur': {'lon': -16.370593820608303, 'lat': -179.997198157699}, 'll': {'lon': -18.30513860368016, 'lat': 177.7304977630865}, 'lr': {'lon': -18.282436575322663, 'lat': -179.96593600310698}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   31.5s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    6.3s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.8s finished
# Preparing scene LE07_L1TP_074072_20130901_mlwater
# Scene path ../data/LE07_L1TP_074072_20130901_tmp/LE07_L1TP_074072_20130901_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130901_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130901_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 576600.0, 'y': -1812600.0}, 'ur': {'x': 819900.0, 'y': -1812600.0}, 'll': {'x': 576600.0, 'y': -2023200.0}, 'lr': {'x': 819900.0, 'y': -2023200.0}}} {'ul': {'lon': -16.393515410889442, 'lat': 177.71734925242927}, 'ur': {'lon': -16.37342208478932, 'lat': 179.99442722286565}, 'll': {'lon': -18.29702636738681, 'lat': 177.72478682720563}, 'lr': {'lon': -18.274448314276466, 'lat': -179.97458023914413}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2
# building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   19.9s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.8s finished
# Preparing scene LE07_L1TP_074072_20130917_mlwater
# Scene path ../data/LE07_L1TP_074072_20130917_tmp/LE07_L1TP_074072_20130917_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20130917_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20130917_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 576900.0, 'y': -1812300.0}, 'ur': {'x': 820200.0, 'y': -1812300.0}, 'll': {'x': 576900.0, 'y': -2024100.0}, 'lr': {'x': 820200.0, 'y': -2024100.0}}} {'ul': {'lon': -16.39079400089166, 'lat': 177.72014858861837}, 'ur': {'lon': -16.370673830761053, 'lat': 179.9971911937743}, 'll': {'lon': -18.305149440149098, 'lat': 177.7276592100495}, 'lr': {'lon': -18.282526536688092, 'lat': -179.9716048472533}}
# LANDSAT_7 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   28.4s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.3s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    5.4s finished
# Preparing scene LE07_L1TP_074072_20131104_mlwater
# Scene path ../data/LE07_L1TP_074072_20131104_tmp/LE07_L1TP_074072_20131104_mlwater/
# {'watermask': {'path': 'LE07_L1TP_074072_20131104_watermask.tif'}, 'waterprob': {'path': 'LE07_L1TP_074072_20131104_waterprob.tif'}}
# {'spatial_reference': 'PROJCS["WGS 84 / UTM zone 60N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",177],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32660"]]', 'geo_ref_points': {'ul': {'x': 575100.0, 'y': -1812600.0}, 'ur': {'x': 818700.0, 'y': -1812600.0}, 'll': {'x': 575100.0, 'y': -2023200.0}, 'lr': {'x': 818700.0, 'y': -2023200.0}}} {'ul': {'lon': -16.393562856473512, 'lat': 177.7033027167065}, 'ur': {'lon': -16.373581536402064, 'lat': 179.98320564662208}, 'll': {'lon': -18.29707968075992, 'lat': 177.71059468509867}, 'lr': {'lon': -18.274627481238337, 'lat': -179.98591753206225}}

# %% [markdown]
# # Walkthrough

# %%
optical_yaml_path = l8_ymls[1]
# optical_yaml_path = s2_ymls[8]
# optical_yaml_path = s1_ymls[8]
# summary_yaml_path = wofssummary_ymls[0]

# %%
# essential input vars
s3_bucket = 'public-eo-data'
s3_dir = 'common_sensing/fiji/mlwater_test/'
inter_dir = '../data/'
coast_buffer = 'common_sensing/ancillary_products/Buffers/Fiji_1kmBuffer_shp'

scene_name = os.path.dirname(optical_yaml_path).split('/')[-1]

inter_dir = f"{inter_dir}{scene_name}_tmp/"
os.makedirs(inter_dir, exist_ok=True)
cog_dir = f"{inter_dir}{scene_name}/"
os.makedirs(cog_dir, exist_ok=True)

yml = f'{inter_dir}datacube-metadata.yaml'
yml_summary = f'{inter_dir}datacube-metadata_watersummary.yaml'

des_band_refs = {
    "LANDSAT_8": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
    "LANDSAT_7": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
    "LANDSAT_5": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
    "LANDSAT_4": ['blue','green','red','nir','swir1','swir2','pixel_qa'],
    "SENTINEL_2": ['blue','green','red','nir','swir1','swir2','scene_classification'],
    "SENTINEL_1": ['vv','vh','layovershadow_mask'],
    "WOFS_SUMMARY": ['pc']}

# %%
# FIND & DOWNLOAD IMAGE DATA
if not os.path.exists(yml):
    s3_download(s3_bucket, optical_yaml_path, yml)
    with open (yml) as stream: yml_meta = yaml.safe_load(stream)
    satellite = yml_meta['platform']['code'] # helper to generalise masking 
    des_bands = des_band_refs[satellite]
    print(satellite, des_bands)
    band_paths_s3 = [os.path.dirname(optical_yaml_path)+'/'+yml_meta['image']['bands'][b]['path'] for b in des_bands ]
    band_paths_local = [inter_dir+os.path.basename(i) for i in band_paths_s3]
    for s3, loc in zip(band_paths_s3, band_paths_local): 
        if not os.path.exists(loc):
            s3_download(s3_bucket, s3, loc)
elif os.path.exists(yml):
    with open (yml) as stream: yml_meta = yaml.safe_load(stream)
    satellite = yml_meta['platform']['code'] # helper to generalise masking 
    des_bands = des_band_refs[satellite]
    print(satellite, des_bands)
else:
    print('boo')

# FIND & DOWNLOAD WATER SUMMARY DATA
if not os.path.exists(yml_summary):
    s3_download(s3_bucket, summary_yaml_path, yml_summary)
    with open (yml_summary) as stream: yml_summary_meta = yaml.safe_load(stream)
    summary = yml_summary_meta['platform']['code']
    des_bands_summary = des_band_refs[summary]
    print(summary, des_bands_summary)
    band_paths_s3 = [os.path.dirname(summary_yaml_path)+'/'+yml_summary_meta['image']['bands'][b]['path'] for b in des_bands_summary ]
    band_paths_local = [inter_dir+os.path.basename(i) for i in band_paths_s3]
    for s3, loc in zip(band_paths_s3, band_paths_local): 
        if not os.path.exists(loc):
            s3_download(s3_bucket, s3, loc)
elif os.path.exists(yml_summary):
    s3_download(s3_bucket, summary_yaml_path, yml_summary)
    with open (yml_summary) as stream: yml_summary_meta = yaml.safe_load(stream)
    summary = yml_summary_meta['platform']['code']
    des_bands_summary = des_band_refs[summary]
    print(summary, des_bands_summary)
    band_paths_s3 = [os.path.dirname(summary_yaml_path)+'/'+yml_summary_meta['image']['bands'][b]['path'] for b in des_bands_summary ]
    band_paths_local = [inter_dir+os.path.basename(i) for i in band_paths_s3]
    for s3, loc in zip(band_paths_s3, band_paths_local): 
        if not os.path.exists(loc):
            s3_download(s3_bucket, s3, loc)
else:
    print('boo')

ref_channel = get_ref_channel(satellite)
qa_channel = get_qa_channel(satellite)
print(ref_channel, qa_channel)
# Out:
# LANDSAT_8 ['blue', 'green', 'red', 'nir', 'swir1', 'swir2', 'pixel_qa']
# WOFS_SUMMARY ['pc']
# swir1 pixel_qa

# %%
summary, des_bands_summary, ref_channel
# Out:
# ('WOFS_SUMMARY', ['pc'], 'swir1')

# %%
# LOAD & PREP IMAGE DATA
o_bands_data = [ xr.open_rasterio(inter_dir + yml_meta['image']['bands'][b]['path']) for b in des_bands ] # loading
o_bands_data = [ resamp_bands(i, o_bands_data) for i in o_bands_data ] # resamp 2 match band 1
bands_data = xr.merge([rename_bands(bd, des_bands, i) for i,bd in enumerate(o_bands_data)]).rename({'band': 'time'}) # ensure band names & dims consistent
bands_data = bands_data.assign_attrs(o_bands_data[0].attrs) # crs etc. needed later
bands_data['time'] = [datetime.strptime(yml_meta['extent']['center_dt'], '%Y-%m-%d %H:%M:%S')] # time dim needed for wofs

img_data = bands_data.isel(time = 0).drop(['time'])
bands_data = None
o_bands_data = None

# %%
# LOAD & PREP WATER SUMMARY DATA
o_bands_data = [ xr.open_rasterio(inter_dir + yml_summary_meta['image']['bands'][b]['path']) for b in des_bands_summary ] # loading
o_bands_data = [ resamp_bands(i, o_bands_data) for i in o_bands_data ]
sum_data = xr.merge([rename_bands(bd, des_bands_summary, i) for i,bd in enumerate(o_bands_data)]).rename({'band': 'time'}) # ensure band names & dims consistent
sum_data = sum_data.assign_attrs(o_bands_data[0].attrs) # crs etc. needed later
sum_data['time'] = [datetime.strptime(yml_summary_meta['extent']['center_dt'], '%Y-%m-%d %H:%M:%S')] # time dim needed for wofs

class_data = sum_data.isel(time = 0).drop(['time']).pc
sum_data = None
o_bands_data = None

# %%
# REPROJECT & ALIGN CRS+DIMS
class_data = class_data.rio.reproject_match(img_data[ref_channel]) # repro + align grid
img_data, class_data = xr.align(img_data, class_data, join="override") # force alignment of x,y precision

# %%
if satellite == 'SENTINEL_1': # catch s1 and scall and re-fromat dtype
    att = img_data.attrs
    img_data = img_data*100
    img_data = img_data.astype('int16')
    img_data.attrs = att

# %%
# VALID REGION MASKS
clearskymask_img = get_valid(img_data, satellite) # img nd mask
clearskymask_class = get_valid(class_data, summary) # water nd mask
clearskymask_train = clearskymask_class.where(clearskymask_class == False, False) # empty mask
clearskymask_train = clearskymask_train.where((clearskymask_img == False) | (clearskymask_class == False), True) # inner true mask

# %%
# ASSIGN WATER/NON WATER CLASS LABELS
water_thresh = 50 # 50% persistence in annual summary
class_data = class_data.where((class_data < water_thresh) | (clearskymask_class == False), 100) # fix > prob to water
class_data = class_data.where((class_data >= water_thresh) | (clearskymask_class == False), 0) # fix < prob to no water

# %%
# MASK TO TRAINING SAMPLES W/ IMPUTED ND
train_data = img_data # dup as use img 4 implementation later
train_data['waterclass'] = class_data # add channel for water mask
train_data = train_data.where(clearskymask_train == True, -9999).drop([qa_channel]) # apply inner mask

# %%
unique, counts = np.unique(train_data.waterclass, return_counts=True)

if (counts[0] < 500) | (counts[1] < 5000):
    raise Exception(f'no class labels should be >5000 for ok classifier. no. training class samples: {counts[0]}{counts[1]}')

# %%
# SPEC & TRAIN MODEL
Y = train_data.waterclass.stack(z=['x','y']) # stack into 1-d arr
X = train_data.drop(['waterclass']).stack(z=['x','y']).to_array().transpose() # stack into transposed 2-d arr

# very shallow classifier - this is a super easy problem & we want it to be fast
wrapper = wrap(RandomForestClassifier(n_estimators=4, 
                               bootstrap = True,
                               max_features = 'sqrt',
                               max_depth=5,
                               n_jobs=2,
                               verbose=2
                              ))
wrapper.estimator.fit(X, Y) # do training
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 2building tree 2 of 2
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   32.3s finished
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=2,
#                        oob_score=False, random_state=None, verbose=2,
#                        warm_start=False)

# %%
# MASK TO FULL VALID IMAGE FOR IMPLEMENTATION
img_data = img_data.drop([qa_channel,'waterclass']) # not sure how these ended up in here(?)
img_data = img_data.where(clearskymask_img == True, -9999) # apply just the img mask this time

# %%
# PREDICT + ASSIGN CONFIDENCE
X = img_data.stack(z=['x','y']).to_array().transpose() # stack into transposed 2-d arr

pred = wrapper.estimator.predict(X) # gen class predictions
pred[pred==100] = 1
prob = wrapper.estimator.predict_proba(X)[:,1]*100 # gen confidence in assigned labels as int
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    4.4s finished

# %%
# RESHAPE OUTPUTS INTO IMAGE
vars_0 = [i for i in X.transpose().to_dataset(dim='variable').data_vars] # get list of vars within img
X_t = X.transpose().to_dataset(dim='variable') # recreate xrds (but no unstacking yet as need to drop in model outputs)
X_t[vars_0[0]].data = pred # add class predictions as first channel
X_t[vars_0[2]].data = prob # add confidence as second channel
X_t = X_t.rename({vars_0[0]:'water_mask',vars_0[1]:'water_prob'}).drop(vars_0[2:]).unstack('z').transpose().astype('int16') # rename + drop vars + unstack xy dims back to 3-d xrds + transpose predictions back into correct orientation
X_t = X_t.where(clearskymask_img,-9999) # ensure probs rm 4 nd regions
X_t.attrs = img_data.attrs

# %%
inter_prodir = inter_dir + scene_name + '_mlwater/'
os.makedirs(inter_prodir, exist_ok=True)
out_mask_prod = inter_prodir + scene_name + '_watermask.tif'
out_prob_prod = inter_prodir + scene_name + '_waterprob.tif'
output_crs = f"EPSG:{X_t.attrs['crs'].split(':')[-1]}"
export_xarray_to_geotiff(X_t, out_mask_prod, bands=['water_mask'], crs=output_crs, x_coord='x', y_coord='y', no_data=-9999)
export_xarray_to_geotiff(X_t, out_prob_prod, bands=['water_prob'], crs=output_crs, x_coord='x', y_coord='y', no_data=-9999)

# %%
create_yaml(inter_prodir, yaml_prep_water(inter_prodir, yml_meta)) # assumes majority of meta copied from original product yml

# %%
s3_upload_cogs(glob.glob(f'{inter_prodir}*'), s3_bucket, s3_dir)

# %%
# Index
cmd = f'python3 ./utils/dataset_index_from_s3_bucket.py {s3_bucket} -p {s3_dir}{scene_name + "_mlwater"}/ --endpoint_url="http://s3-uk-1.sa-catapult.co.uk" --unsigned_requests --start_date 1960-01-01 --end_date 2030-01-01'
p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
out = p.stdout.read()
print(out)

# %%
fig, ax = plt.subplots(figsize=(50,50))
ax.imshow(img_data.where(clearskymask_img)[ref_channel])

# %%
fig, ax = plt.subplots(figsize=(50,50))
ax.imshow(X_t.where(X_t.water_mask>=0).water_mask)

# %%
fig, ax = plt.subplots(figsize=(50,50))
ax.imshow(X_t.where(X_t.water_prob>=0).water_prob)
